# %%
import pandas as pd
df = pd.DataFrame([['我','你','他'],[5,6,7],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])
df.info()
# Out:
# Running cells with 'Python 3.7.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/22065/AppData/Local/Programs/Python/Python37/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import pandas as pd
df = pd.DataFrame([[2,3,4],[5,6,7],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])
df
# Out:
#    A  B  C
# x  2  3  4
# y  5  6  7
# z  7  8  9

# %%
import pandas as pd
df = pd.DataFrame([[2,3,4],[5,6,7],[7,8,9],[10,11,12]],columns=['A','B','C'],index=['x','y','z','u'])
df.shape
# Out:
# (4, 3)

# %%
import pandas as pd
df = pd.DataFrame([[2,3,4],[5,6,7],[7,8,9]],columns=['A','B','C'],index=['x','y','z'])
df.describe()
# Out:
#               A         B         C
# count  3.000000  3.000000  3.000000
# mean   4.666667  5.666667  6.666667
# std    2.516611  2.516611  2.516611
# min    2.000000  3.000000  4.000000
# 25%    3.500000  4.500000  5.500000
# 50%    5.000000  6.000000  7.000000
# 75%    6.000000  7.000000  8.000000
# max    7.000000  8.000000  9.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['A'].plot(kind='hist', bins=20, title='A')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['B'].plot(kind='hist', bins=20, title='B')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['C'].plot(kind='hist', bins=20, title='C')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='A', y='B', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='B', y='C', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['A'].plot(kind='line', figsize=(8, 4), title='A')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['B'].plot(kind='line', figsize=(8, 4), title='B')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['C'].plot(kind='line', figsize=(8, 4), title='C')
# plt.gca().spines[['top', 'right']].set_visible(False)
