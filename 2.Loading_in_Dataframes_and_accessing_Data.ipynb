# %% [markdown]
# <a href="https://colab.research.google.com/github/Given-cpu/Pandas-/blob/main/Loading_in_Dataframes_and_accessing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
results = pd.read_parquet('/content/results.parquet')
results.head()
results.tail()
# Out:
#           year    type              discipline                          event  \
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
#                           as  athlete_id   noc    team  place   tied medal
# 308403         Marián Skupek      148983   SVK    None   26.0  False  None
# 308404         Elsa Fermbäck      148984   SWE    None   28.0  False  None
# 308405         Hilma Lövblom      148985   SWE  Sweden   13.0  False  None
# 308406         Hilma Lövblom      148985   SWE    None    NaN  False  None
# 308407  Charlotta Säfvenberg      148986  None    None   24.0  False  None

# %%
import pandas as pd
permites_data = pd.read_excel('/content/permits-by-nationality-2024.xlsx', sheet_name='Sheet1')
permites_data.head()
# Out:
#    Nationality   Issued  Refused  Withdrawn
# 0  Grand Total  39390.0   2456.0     1064.0
# 1  Afghanistan     16.0      NaN        1.0
# 2      Albania     38.0      5.0        NaN
# 3      Algeria     35.0      6.0        NaN
# 4       Angola      3.0      NaN        NaN

# %%
 import pandas as pd
results = pd.read_parquet('/content/results.parquet')
tryhard = pd.read_excel('/content/permits-by-nationality-2024.xlsx', sheet_name='Sheet1')
results.to_excel
# Out:
# <bound method NDFrame.to_excel of           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
results.sample(3,random_state=1)
# Out:
#           year    type                        discipline  \
# 288565  2020.0  Summer                            Boxing
# 57866   1972.0  Summer  Artistic Gymnastics (Gymnastics)
# 62957   1952.0  Summer  Artistic Gymnastics (Gymnastics)
#
#                                   event            as  athlete_id  noc  team  \
# 288565         Flyweight, Men (Olympic)    Yoel Finol      136459  VEN  None
# 57866   Floor Exercise, Women (Olympic)   Cathy Rigby       29279  USA  None
# 62957     Horizontal Bar, Men (Olympic)  Frank Turner       30180  GBR  None
#
#         place  tied medal
# 288565   17.0  True  None
# 57866     9.0  True  None
# 62957   106.0  True  None

# %%
import pandas as pd
coffee = pd.read_csv('https://raw.githubusercontent.com/Given-cpu/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.head(5)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
import pandas as pd
coffee = pd.read_csv('https://raw.githubusercontent.com/Given-cpu/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.loc[[0,1,4]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 4  Wednesday    Espresso          35

# %%
coffee.loc[5:9:2,['Day','Units Sold']]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 7   Thursday          30
# 9     Friday          35

# %%
coffee.iloc[5:9:2,[0,2]]
# Out:
#          Day  Units Sold
# 5  Wednesday          25
# 7   Thursday          30

# %%
coffee.index = coffee['Day']
coffee.head()
coffee.loc['Wednesday','Units Sold']
# Out:
# Day
# Wednesday    35
# Wednesday    25
# Name: Units Sold, dtype: int64

# %%
coffee.iloc[2,0] = 10
coffee.head()
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso        25.0
# Monday        Monday       Latte        15.0
# Tuesday           10    Espresso        10.0
# Tuesday      Tuesday       Latte        20.0
# Wednesday  Wednesday    Espresso        35.0

# %%
coffee.iat[2,0]
# Out:
# 10

# %%
import pandas as pd
coffee = pd.read_csv('https://raw.githubusercontent.com/Given-cpu/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')
coffee.sort_values(['Units Sold'])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
coffee.sort_values(['Units Sold','Coffee Type'],ascending=[1,0])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 0      Monday    Espresso          25
# 7    Thursday       Latte          30
# 2     Tuesday    Espresso          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
for index, row in coffee.iterrows():
  print(index,row['Coffee Type'])
# Out:
# 0 Espresso
# 1 Latte
# 2 Espresso
# 3 Latte
# 4 Espresso
# 5 Latte
# 6 Espresso
# 7 Latte
# 8 Espresso
# 9 Latte
# 10 Espresso
# 11 Latte
# 12 Espresso
# 13 Latte

# %%
for index, row in coffee.iterrows():
  print(index)
  print(row)
  print("\n\n\n")
# Out:
# 0
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object
#
#
#
#
# 1
# Day            Monday
# Coffee Type     Latte
# Units Sold         15
# Name: 1, dtype: object
#
#
#
#
# 2
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object
#
#
#
#
# 3
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object
#
#
#
#
# 4
# Day            Wednesday
# Coffee Type     Espresso
# Units Sold            35
# Name: 4, dtype: object
#
#
#
#
# 5
# Day            Wednesday
# Coffee Type        Latte
# Units Sold            25
# Name: 5, dtype: object
#
#
#
#
# 6
# Day            Thursday
# Coffee Type    Espresso
# Units Sold           40
# Name: 6, dtype: object
#
#
#
#
# 7
# Day            Thursday
# Coffee Type       Latte
# Units Sold           30
# Name: 7, dtype: object
#
#
#
#
# 8
# Day              Friday
# Coffee Type    Espresso
# Units Sold           45
# ...
